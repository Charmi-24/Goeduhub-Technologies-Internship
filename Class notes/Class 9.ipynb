# %%
import numpy as np
import pandas as pd

df = pd.read_csv("/content/student_data.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Id      10 non-null     int64
#  1   CS      6 non-null      float64
#  2   Math    6 non-null      float64
#  3   Name    8 non-null      object
# dtypes: float64(2), int64(1), object(1)
# memory usage: 448.0+ bytes

# %%
df
# Out:
#    Id    CS  Math        Name
# 0   1  50.0  46.0     Average
# 1   2   NaN  70.0        Good
# 2   3  88.0   NaN  Execellent
# 3   4   NaN  74.0         NaN
# 4   5  63.0   NaN     Average
# 5   6   NaN   NaN  Execellent
# 6   7   NaN   NaN         NaN
# 7   8  53.0  45.0     Average
# 8   9  60.0  62.0        Good
# 9  10  55.0  65.0        Good

# %%
df.fillna(0)
# Out:
#    Id    CS  Math        Name
# 0   1  50.0  46.0     Average
# 1   2   0.0  70.0        Good
# 2   3  88.0   0.0  Execellent
# 3   4   0.0  74.0           0
# 4   5  63.0   0.0     Average
# 5   6   0.0   0.0  Execellent
# 6   7   0.0   0.0           0
# 7   8  53.0  45.0     Average
# 8   9  60.0  62.0        Good
# 9  10  55.0  65.0        Good

# %%
new_df = df.fillna({'CS':0, 'Math':0, 'Name': 'No Category'})

# %%
new_df
# Out:
#    Id    CS  Math         Name
# 0   1  50.0  46.0      Average
# 1   2   0.0  70.0         Good
# 2   3  88.0   0.0   Execellent
# 3   4   0.0  74.0  No Category
# 4   5  63.0   0.0      Average
# 5   6   0.0   0.0   Execellent
# 6   7   0.0   0.0  No Category
# 7   8  53.0  45.0      Average
# 8   9  60.0  62.0         Good
# 9  10  55.0  65.0         Good

# %%
new_df = df.fillna(method = 'ffill') #forward fill
new_df
# Out:
#    Id    CS  Math        Name
# 0   1  50.0  46.0     Average
# 1   2  50.0  70.0        Good
# 2   3  88.0  70.0  Execellent
# 3   4  88.0  74.0  Execellent
# 4   5  63.0  74.0     Average
# 5   6  63.0  74.0  Execellent
# 6   7  63.0  74.0  Execellent
# 7   8  53.0  45.0     Average
# 8   9  60.0  62.0        Good
# 9  10  55.0  65.0        Good

# %%
new_df = df.fillna(method = 'bfill') #backward fill
new_df
# Out:
#    Id    CS  Math        Name
# 0   1  50.0  46.0     Average
# 1   2  88.0  70.0        Good
# 2   3  88.0  74.0  Execellent
# 3   4  63.0  74.0     Average
# 4   5  63.0  45.0     Average
# 5   6  53.0  45.0  Execellent
# 6   7  53.0  45.0     Average
# 7   8  53.0  45.0     Average
# 8   9  60.0  62.0        Good
# 9  10  55.0  65.0        Good

# %%
new_df = df.fillna(method = 'bfill',axis = 'columns') # index for row and columns for columns
new_df
# Out:
#    Id          CS        Math        Name
# 0   1          50          46     Average
# 1   2          70          70        Good
# 2   3          88  Execellent  Execellent
# 3   4          74          74         NaN
# 4   5          63     Average     Average
# 5   6  Execellent  Execellent  Execellent
# 6   7         NaN         NaN         NaN
# 7   8          53          45     Average
# 8   9          60          62        Good
# 9  10          55          65        Good

# %%
new_df = df.fillna(method = 'ffill', limit = 1)
new_df
# limit will limit the number of values to want to fill
# Out:
#    Id    CS  Math        Name
# 0   1  50.0  46.0     Average
# 1   2  50.0  70.0        Good
# 2   3  88.0  70.0  Execellent
# 3   4  88.0  74.0  Execellent
# 4   5  63.0  74.0     Average
# 5   6  63.0   NaN  Execellent
# 6   7   NaN   NaN  Execellent
# 7   8  53.0  45.0     Average
# 8   9  60.0  62.0        Good
# 9  10  55.0  65.0        Good

# %%
#new_df = df.fillna(method = 'ffill', limit = 1, inplace = True)
#to change the original dataset

# %%
newdf = df.interpolate()
newdf
# Out:
#    Id         CS   Math        Name
# 0   1  50.000000  46.00     Average
# 1   2  69.000000  70.00        Good
# 2   3  88.000000  72.00  Execellent
# 3   4  75.500000  74.00         NaN
# 4   5  63.000000  66.75     Average
# 5   6  59.666667  59.50  Execellent
# 6   7  56.333333  52.25         NaN
# 7   8  53.000000  45.00     Average
# 8   9  60.000000  62.00        Good
# 9  10  55.000000  65.00        Good

# %%
newdf = df.dropna()
newdf
# Out:
#    Id    CS  Math     Name
# 0   1  50.0  46.0  Average
# 7   8  53.0  45.0  Average
# 8   9  60.0  62.0     Good
# 9  10  55.0  65.0     Good

# %%
newdf = df.dropna(how = 'all') # only the deletes the rows where the values of all the columns are nan
newdf
# Out:
#    Id    CS  Math        Name
# 0   1  50.0  46.0     Average
# 1   2   NaN  70.0        Good
# 2   3  88.0   NaN  Execellent
# 3   4   NaN  74.0         NaN
# 4   5  63.0   NaN     Average
# 5   6   NaN   NaN  Execellent
# 6   7   NaN   NaN         NaN
# 7   8  53.0  45.0     Average
# 8   9  60.0  62.0        Good
# 9  10  55.0  65.0        Good

# %%
newdf = df.dropna(thresh=2)  #we can keep columns with 2 null values but more than that will be deleted
newdf
# Out:
#    Id    CS  Math        Name
# 0   1  50.0  46.0     Average
# 1   2   NaN  70.0        Good
# 2   3  88.0   NaN  Execellent
# 3   4   NaN  74.0         NaN
# 4   5  63.0   NaN     Average
# 5   6   NaN   NaN  Execellent
# 7   8  53.0  45.0     Average
# 8   9  60.0  62.0        Good
# 9  10  55.0  65.0        Good

# %%
newdf = df.replace(np.nan, 999)
newdf
# Out:
#    Id     CS   Math        Name
# 0   1   50.0   46.0     Average
# 1   2  999.0   70.0        Good
# 2   3   88.0  999.0  Execellent
# 3   4  999.0   74.0         999
# 4   5   63.0  999.0     Average
# 5   6  999.0  999.0  Execellent
# 6   7  999.0  999.0         999
# 7   8   53.0   45.0     Average
# 8   9   60.0   62.0        Good
# 9  10   55.0   65.0        Good

# %%
newdf = df.replace(np.nan,{'CS': 999, 'Math':0,'Name':'No Category'})

# %%
newdf
# Out:
#    Id     CS  Math         Name
# 0   1   50.0  46.0      Average
# 1   2  999.0  70.0         Good
# 2   3   88.0   0.0   Execellent
# 3   4  999.0  74.0  No Category
# 4   5   63.0   0.0      Average
# 5   6  999.0   0.0   Execellent
# 6   7  999.0   0.0  No Category
# 7   8   53.0  45.0      Average
# 8   9   60.0  62.0         Good
# 9  10   55.0  65.0         Good

# %% [markdown]
# # Boston Housing Price Prediction

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import sklearn
from sklearn.linear_model import LinearRegression

# %%
from sklearn.datasets import load_boston

# %%
boston = load_boston()
boston
# Out:
# {'DESCR': ".. _boston_dataset:\n\nBoston house prices dataset\n---------------------------\n\n**Data Set Characteristics:**  \n\n    :Number of Instances: 506 \n\n    :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.\n\n    :Attribute Information (in order):\n        - CRIM     per capita crime rate by town\n        - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.\n        - INDUS    proportion of non-retail business acres per town\n        - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)\n        - NOX      nitric oxides concentration (parts per 10 million)\n        - RM       average number of rooms per dwelling\n        - AGE      proportion of owner-occupied units built prior to 1940\n        - DIS      weighted distances to five Boston employment centres\n        - RAD      index of accessibility to radial highways\n        - TAX      full-value property-tax rate
# ...

# %%
boston.keys()
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename'])

# %%
boston['data'].shape
# Out:
# (506, 13)

# %%
df = pd.DataFrame(boston['data'])
#df = pd.DataFrame(boston.data)

# %%
df.head()
# Out:
#         0     1     2    3      4   ...   8      9     10      11    12
# 0  0.00632  18.0  2.31  0.0  0.538  ...  1.0  296.0  15.3  396.90  4.98
# 1  0.02731   0.0  7.07  0.0  0.469  ...  2.0  242.0  17.8  396.90  9.14
# 2  0.02729   0.0  7.07  0.0  0.469  ...  2.0  242.0  17.8  392.83  4.03
# 3  0.03237   0.0  2.18  0.0  0.458  ...  3.0  222.0  18.7  394.63  2.94
# 4  0.06905   0.0  2.18  0.0  0.458  ...  3.0  222.0  18.7  396.90  5.33
#
# [5 rows x 13 columns]

# %%
boston.feature_names
# Out:
# array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'B', 'LSTAT'], dtype='<U7')

# %%
print(boston.DESCR)
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
# ...

# %%
print(boston.target)
# Out:
# [24.  21.6 34.7 33.4 36.2 28.7 22.9 27.1 16.5 18.9 15.  18.9 21.7 20.4
#  18.2 19.9 23.1 17.5 20.2 18.2 13.6 19.6 15.2 14.5 15.6 13.9 16.6 14.8
#  18.4 21.  12.7 14.5 13.2 13.1 13.5 18.9 20.  21.  24.7 30.8 34.9 26.6
#  25.3 24.7 21.2 19.3 20.  16.6 14.4 19.4 19.7 20.5 25.  23.4 18.9 35.4
#  24.7 31.6 23.3 19.6 18.7 16.  22.2 25.  33.  23.5 19.4 22.  17.4 20.9
#  24.2 21.7 22.8 23.4 24.1 21.4 20.  20.8 21.2 20.3 28.  23.9 24.8 22.9
#  23.9 26.6 22.5 22.2 23.6 28.7 22.6 22.  22.9 25.  20.6 28.4 21.4 38.7
#  43.8 33.2 27.5 26.5 18.6 19.3 20.1 19.5 19.5 20.4 19.8 19.4 21.7 22.8
#  18.8 18.7 18.5 18.3 21.2 19.2 20.4 19.3 22.  20.3 20.5 17.3 18.8 21.4
#  15.7 16.2 18.  14.3 19.2 19.6 23.  18.4 15.6 18.1 17.4 17.1 13.3 17.8
#  14.  14.4 13.4 15.6 11.8 13.8 15.6 14.6 17.8 15.4 21.5 19.6 15.3 19.4
#  17.  15.6 13.1 41.3 24.3 23.3 27.  50.  50.  50.  22.7 25.  50.  23.8
#  23.8 22.3 17.4 19.1 23.1 23.6 22.6 29.4 23.2 24.6 29.9 37.2 39.8 36.2
# ...

# %%
df.head(2)
# Out:
#         0     1     2    3      4   ...   8      9     10     11    12
# 0  0.00632  18.0  2.31  0.0  0.538  ...  1.0  296.0  15.3  396.9  4.98
# 1  0.02731   0.0  7.07  0.0  0.469  ...  2.0  242.0  17.8  396.9  9.14
#
# [2 rows x 13 columns]

# %%
df.columns = boston.feature_names

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX  ...  RAD    TAX  PTRATIO       B  LSTAT
# 0  0.00632  18.0   2.31   0.0  0.538  ...  1.0  296.0     15.3  396.90   4.98
# 1  0.02731   0.0   7.07   0.0  0.469  ...  2.0  242.0     17.8  396.90   9.14
# 2  0.02729   0.0   7.07   0.0  0.469  ...  2.0  242.0     17.8  392.83   4.03
# 3  0.03237   0.0   2.18   0.0  0.458  ...  3.0  222.0     18.7  394.63   2.94
# 4  0.06905   0.0   2.18   0.0  0.458  ...  3.0  222.0     18.7  396.90   5.33
#
# [5 rows x 13 columns]

# %%
df['Price'] = boston.target

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX  ...    TAX  PTRATIO       B  LSTAT  Price
# 0  0.00632  18.0   2.31   0.0  0.538  ...  296.0     15.3  396.90   4.98   24.0
# 1  0.02731   0.0   7.07   0.0  0.469  ...  242.0     17.8  396.90   9.14   21.6
# 2  0.02729   0.0   7.07   0.0  0.469  ...  242.0     17.8  392.83   4.03   34.7
# 3  0.03237   0.0   2.18   0.0  0.458  ...  222.0     18.7  394.63   2.94   33.4
# 4  0.06905   0.0   2.18   0.0  0.458  ...  222.0     18.7  396.90   5.33   36.2
#
# [5 rows x 14 columns]

# %%
y = df['Price']
X = df.drop('Price', axis = 1)  # axis = 1 means entire column means all the rows are dropped

# %%
X.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX  ...  RAD    TAX  PTRATIO       B  LSTAT
# 0  0.00632  18.0   2.31   0.0  0.538  ...  1.0  296.0     15.3  396.90   4.98
# 1  0.02731   0.0   7.07   0.0  0.469  ...  2.0  242.0     17.8  396.90   9.14
# 2  0.02729   0.0   7.07   0.0  0.469  ...  2.0  242.0     17.8  392.83   4.03
# 3  0.03237   0.0   2.18   0.0  0.458  ...  3.0  222.0     18.7  394.63   2.94
# 4  0.06905   0.0   2.18   0.0  0.458  ...  3.0  222.0     18.7  396.90   5.33
#
# [5 rows x 13 columns]

# %%
y.head()
# Out:
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# Name: Price, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = lm.predict(X_test)

# %%
df1 = pd.DataFrame(y_pred, y_test)
df1.head()
# Out:
#                0
# Price
# 23.6   28.534695
# 32.4   36.618701
# 13.6   15.637511
# 22.8   25.501450
# 16.1   18.709673

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test,y_pred)
print(mse)
# Out:
# 20.72402343733962

# %% [markdown]
# # Visualization
