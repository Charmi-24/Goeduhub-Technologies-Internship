# %%
import numpy as np

# %% [markdown]
# # Python Code

# %%
print('hello')
# Out:
# hello

# %%
a=10
b=20
c=a+b
print(c)
# Out:
# 30

# %%
a=input("enter the value")
# Out:
# enter the value10

# %%
print(a)
# Out:
# 10

# %%
print(type(a))
# Out:
# <class 'str'>

# %%
b=int(input("enter the value"))
c=int(input("enter the value"))
d=b+c
print(d)
# Out:
# enter the value10
# enter the value20
# 30

# %%
#hello

# %% [markdown]
# # Variables

# %%
a=10
b="goeduhub"
print(a,b)
# Out:
# 10 goeduhub

# %%
x=y=z=10
print(x)
print(y)
print(z)
# Out:
# 10
# 10
# 10

# %%
if a==b:
  print(a)
else:
  print(b)
# Out:
# goeduhub
