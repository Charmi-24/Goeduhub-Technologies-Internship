# %%
l1 = [1,2,3]
l2 = ['apple', 'orange', 'banana', 'mango', 'grapes']

l=[]
#list

t = (1,2,3,4)
l = list(t)
print(l)
# Out:
# [1, 2, 3, 4]

# %%
l = []
n = int(input("enter no of elements"))
for i in range(n):
  item = input("enter element value")
  l.append(item) #append is in-built function for python lists
print(l)
# Out:
# enter no of elements2
# enter element valuea
# enter element valueb
# ['a', 'b']

# %% [markdown]
# #Accessing elements of list

# %%
# indexing
l[0]
# Out:
# 'a'

# %%
l[-1]
# Out:
# 'b'

# %%
# l[2:4]

# %%
l[1]='acd' #updating or replacing an element
print(l)
# Out:
# ['a', 'acd']

# %%
l.insert(0,'ML')
print(l)
# Out:
# ['ML', 'a', 'acd']

# %%
l = [10,20,['a', 'b', 'c'],50]
print(l)
#nested list
# Out:
# [10, 20, ['a', 'b', 'c'], 50]

# %%
print(l)
# Out:
# [1, 2, 3, 4]

# %%
l.remove(2)

# %%
l
# Out:
# [1, 3, 4]

# %%
l.pop(2)
# Out:
# 4

# %%
del l[0]

# %%
l
# Out:
# [3]

# %%
# deleting the entire list using del l #

# %%
l = [1,2,3,4]
l.clear()
print(l)
# Out:
# []

# %%
l = [1,2,3,4]
l.count(2)
# Out:
# 1

# %% [markdown]
# # Tuple

# %%
# immutable

# %% [markdown]
# # dictionary

# %%
# key and value
d=dict()
print(d)
type(d)
b = {} #declaring a dictionary
# Out:
# {}
# dict

# %%
a = dict({1:'red', 2:'blue', 3:'green' })

# %%
a
# Out:
# {1: 'red', 2: 'blue', 3: 'green'}

# %%
# creating a dictionary from two lists
l1 = ['red', 'green', 'blue']
l2 = [1,2,3]
d = dict(zip(l1,l2))
d
# Out:
# {'blue': 3, 'green': 2, 'red': 1}

# %%
# using zip function
# called iterables

# %%
d.keys()
# Out:
# dict_keys(['red', 'green', 'blue'])

# %%
d.values()
# Out:
# dict_values([1, 2, 3])

# %%
d.items()
# Out:
# dict_items([('red', 1), ('green', 2), ('blue', 3)])

# %%
for i in d:
  print(i)
  print(d[i])
# Out:
# red
# 1
# green
# 2
# blue
# 3

# %%
for i in d.values():
  print(i)
# Out:
# 1
# 2
# 3

# %%
d.get('blue')
# Out:
# 3

# %%
d['blue']
# Out:
# 3

# %%
d['blue']=200
print(d)
# Out:
# {'red': 1, 'green': 2, 'blue': 200}

# %%
d['orange'] = 100

# %%
d
# Out:
# {'blue': 200, 'green': 2, 'orange': 100, 'red': 1}

# %%
print(d)
# Out:
# {'red': 1, 'green': 2, 'blue': 200, 'orange': 100}

# %%
p = {10:'hello',20:'abc'}

# %%
print(d)
print(p)
# Out:
# {'red': 1, 'green': 2, 'blue': 200, 'orange': 100}
# {10: 'hello', 20: 'abc'}

# %%
d.update(p)
print(d)
# Out:
# {'red': 1, 'green': 2, 'blue': 200, 'orange': 100, 10: 'hello', 20: 'abc'}

# %%
# merging two dictionaries with the help of update function

# %%
len(d)
# Out:
# 6

# %%
d.pop('red')
# Out:
# 1

# %%
print(d)
# Out:
# {'green': 2, 'blue': 200, 'orange': 100, 10: 'hello', 20: 'abc'}

# %%
d.clear()

# %%
k = d.keys()

# %% [markdown]
# # Set

# %%
s = {1,2,3,4,5}
print(s)
print(type(s))
# Out:
# {1, 2, 3, 4, 5}
# <class 'set'>

# %%
s = set(['a', 'b','c','d'])
print(s)
# Out:
# {'a', 'b', 'd', 'c'}

# %%
s = {1,2,3,4,2,3,4}
print(s)
# Out:
# {1, 2, 3, 4}

# %%
s.add('a')
print(s)
# Out:
# {1, 2, 3, 4, 'a'}

# %%
s.update(['hello', 'abc'])
print(s)
# Out:
# {1, 2, 3, 4, 'hello', 'abc', 'a'}

# %%
s.remove(1)

# %%
s
# Out:
# {2, 3, 4, 'a', 'abc', 'hello'}

# %%
for i in s:
  print(i)
# Out:
# 2
# 3
# 4
# hello
# abc
# a
