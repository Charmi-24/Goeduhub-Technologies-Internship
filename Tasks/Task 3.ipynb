# %% [markdown]
# ***CHARMI YASHWANT KANANI***
#
# ***GO_STP_755***

# %% [markdown]
# DICTIONARIES

# %% [markdown]
# Q.1 Write a Python Program to sort (ascending and descending) a dictionary by value.

# %%
d = {1: 1, 2: 9, 3: 4, 5:6}
sv = sorted(d.values()) 
sd = {}

for i in sv:
  for k in d.keys():
    if d[k] == i:
      sd[k] = d[k]
print(sd)
# Out:
# {1: 1, 3: 4, 5: 6, 2: 9}

# %%
d = {1: 1, 2: 9, 3: 4, 5:6}
sv = sorted(d.values(),reverse = True) 
sd = {}

for i in sv:
  for k in d.keys():
    if d[k] == i:
      sd[k] = d[k]
print(sd)
# Out:
# {2: 9, 5: 6, 3: 4, 1: 1}

# %% [markdown]
# Q.2 Write a Python Program to add a key to a dictionary.
#
# Sample Dictionary : {0: 10, 1: 20}
# Expected Result : {0: 10, 1: 20, 2: 30}

# %%
a = {0: 10, 1: 20}
a[2] = 30
a
# Out:
# {0: 10, 1: 20, 2: 30}

# %% [markdown]
# Q.3 Write a  program asks for City name and Temperature and builds a dictionary using that Later on you can input City name and it will tell you the Temperature of that City.

# %%
d = {}
n = int(input("Enter no of cities: "))
for i in range(n):
  city = input("Enter the name of city: ")
  temp = int(input("Enter the temperature: "))
  d[city] = temp
print(d)  

enter = input("enter the city to get the temp: ")
print("the temp is: ", d[enter])
# Out:
# Enter no of cities: 4
# Enter the name of city: a
# Enter the temperature: 45
# Enter the name of city: b
# Enter the temperature: 34
# Enter the name of city: c
# Enter the temperature: 6
# Enter the name of city: d
# Enter the temperature: 56
# {'a': 45, 'b': 34, 'c': 6, 'd': 56}
# 45

# %% [markdown]
# Q. 4 Write a Python program to convert list to list of dictionaries.
#
# Sample lists: ["Black", "Red", "Maroon", "Yellow"], ["#000000", "#FF0000", "#800000", "#FFFF00"]
#
# Expected Output: [{'color_name': 'Black', 'color_code': '#000000'}, {'color_name': 'Red', 'color_code': '#FF0000'}, {'color_name': 'Maroon', 'color_code': '#800000'}, {'color_name': 'Yellow', 'color_code': '#FFFF00'}]

# %%
a = ["Black", "Red", "Maroon", "Yellow"]
b = ["#000000", "#FF0000", "#800000", "#FFFF00"]
keys = ['color_name', 'color_code']

nl = []
for i in range(4):
    nl.append({keys[0]: a[i], keys[1] : b[i]})
print(nl)
# Out:
# [{'color_name': 'Black', 'color_code': '#000000'}, {'color_name': 'Red', 'color_code': '#FF0000'}, {'color_name': 'Maroon', 'color_code': '#800000'}, {'color_name': 'Yellow', 'color_code': '#FFFF00'}]

# %% [markdown]
# Q. 5 We have following information on Employees and their Salary (Salary is in lakhs),
#
# Employee	Salary
#
# John	14
#
# Smith	13
#
# Alice	32
#
# Daneil	21
#
# Using above create a dictionary of Employees and their Salary
# Write a program that asks user for three type of inputs,
#
# print: if user enter print then it should print all Employees with their Salary in this format,
#
# John ==>14
#
# Smith ==>13
#
# Alice ==>32
#
# Daneil ==>21
#
# add: if user input adds then it should further ask for an Employee name to add. If Employee already exists in our dataset then it should print that it exists and do nothing. If it doesn't then it asks for Salary and add that new Employee/Salary in our dictionary and print it
#
# remove: when user inputs remove it should ask for an Employee to remove. If an Employee exists in our dictionary then remove it and print a new dictionary using format shown above in (a). Else print that Employee doesn't exist!
#
# query: on this again ask the user for which Employee he or she wants to query. When a user inputs that Employee it will print the Salary of that Employee.

# %%
d = {'John': 14, 'Smith': 13, 'Alice': 32, 'Daneil' : 21}
ui = input("You can print, add, remove, query. please enter: ")
if ui == "print":
  for k,v in d.items():
    print(k + " ==>",v)
if ui == "add":
  name = input("enter the name of employee")
  if name in d:
    print("the name exists")
  if name not in d:
    sal = int(input("enter the sal in lakhs"))
    d[name] = sal
    print(d)
if ui == "remove":
  nm = input("enter the name of employee you want to remove")
  if nm in d:
    d.pop(nm)
    for k,v in d.items():
      print(k + " ==>",v)
  else:
    print("the name does not exist")
if ui == "query":
  n = input("enter the name of employee you want the sal of ")
  print("the salary is ", d[n])
# Out:
# You can print, add, remove, query. please enter: query
# enter the name of employee you want the sal ofJohn
# the salary is  14

# %% [markdown]
# SETS

# %% [markdown]
#  Q.1 What is the difference between a set and a frozenset? Create any set and try to use frozenset(setname).

# %%
# Set is an in-built mutable data type used for storing multiple items under a variable.
# It is unordered and unindexed. Sets do not have duplicate values which means the occurrence of each element in a set is once.

# A frozen set is just an immutable version of a Python set object. 
# While elements of a set can be modified at any time, elements of the frozen set remain the same after creation.

a = {1,2,3}
b = frozenset(a)
print(type(a))
print(type(b))
# Out:
# <class 'set'>
# <class 'frozenset'>

# %% [markdown]
# Q.2 Find the elements in a given set that are not in another set
#
#     set1 = {10,20,30,40,50}
#
#     set2 = {40,50,60,70,80}
#
#  Difference between set1 and set2 is {10,20,30}

# %%
set1 = {10,20,30,40,50}
set2 = {40,50,60,70,80}
set1.difference(set2)
# Out:
# {10, 20, 30}
