# %% [markdown]
# ***CHARMI YASHWANT KANANI***
#
# ***GO_STP_755***

# %% [markdown]
# QUESTION 1

# %% [markdown]
# We are having 3 list like this
#
# Colors = [“Yellow”,”Green”,”White”,”Black”]
#
# Fruits=[“Apple”,”Papaya”,”Mango”,”Orange”]
#
# Animals=[“Tiger”,”Lion”,”Deer”,”Zebra”]
#
#   i. Write a program that asks user to enter a Color/Fruit/Animal name and it should tell which category belongs to , like its is a fruit or color or Animal

# %%
Colors = ["Yellow","Green","White","Black"]
Fruits = ["Apple","Papaya","Mango","Orange"]
Animals = ["Tiger","Lion","Deer","Zebra"]

user_input = input("Enter the name of a color, fruit or an animal: ")

if user_input in Colors:
  print(user_input, "is a color.")
elif user_input in Fruits:
  print(user_input, "is a fruit.")
elif user_input in Animals:
  print(user_input, "is an animal.")
else:
  print("Invalid Entry")
# Out:
# Enter the name of a color, fruit or an animal: Yellow
# Yellow is a color.

# %% [markdown]
#  ii. Write a program that asks user to enter two cities and it tells you if they both are in same country or not. For example if I enter yellow and Black, it will print "Both are colors" but if I enter yellow and Tiger it should print "They don't belong to same category"

# %%
user_input1 = input("Enter the name of a color or an animal: ")
user_input2 = input("Enter the name of a color or an animal: ")

if user_input1 in Colors and user_input2 in Colors:
  print("Both are colors.")
elif user_input1 in Animals and user_input2 in Animals:
  print("Both are Animals.")
else:
  print("They don't belong to same category.")
# Out:
# Enter the name of a color or an animal: Yellow
# Enter the name of a color or an animal: Tiger
# They don't belong to same category.

# %% [markdown]
# QUESTION 2

# %% [markdown]
# Write a python program that can tell you if your grade score good or not . Normal Score range is 40 to 60.
#
#   i. Ask user to enter his score.
#
#   ii. If it is below 40 to 60 range then print that score is low
#
#   iii. If it is above 60 then print that it is good otherwise print that it is normal

# %%
user_input = int(input("Enter the marks: "))
if user_input < 40:
  print("The score is low.")
elif user_input > 60:
  print("The score is good.")
else:
  print("The score is normal.")
# Out:
# Enter the marks: 60
# The score is normal.

# %% [markdown]
# QUESTION 3

# %% [markdown]
# After appearing in exam 10 times you got this result,
#
# result = ["Pass","Fail","Fail","Pass","Fail","Pass","Pass","Fail","Fail","Fail"]
#
# Using for loop figure out how many times you got Pass

# %%
result = ["Pass","Fail","Fail","Pass","Fail","Pass","Pass","Fail","Fail","Fail"]
j = 0
for i in result:
  if i == "Pass":
    j += 1
print(j)
# Out:
# 4

# %% [markdown]
# QUESTION 4

# %% [markdown]
# Write a program that prints following shape

# %%
for i in range(1,5):
  for j in range(i):
    print("*",end="")
  print()
for i in range(5,0,-1):
  for j in range(i):
    print("*",end="")
  print()
# Out:
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *

# %% [markdown]
# QUESTION 5

# %% [markdown]
# Lets say you are running a 50 km race. Write a program that,
#
# Upon completing each 10 km asks you "are you tired?"
#
# If you reply "yes" then it should break and print "you didn't finish the race"
#
#  If you reply "no" then it should continue and ask "are you tired" on every km
#
# If you finish all 50 km then it should print congratulations message

# %%
for i in range(1,51):
  if i % 10 == 0:
    enter = input("are you tired?")
    if enter == "yes":
      print("you didn't finish the race")
      break
    if enter == "no":
      if i == 50:
        print("congratulations")
      continue
# Out:
# are you tired?no
# are you tired?no
# are you tired?no
# are you tired?no
# are you tired?no
# congratulations

# %% [markdown]
# QUESTION 6

# %% [markdown]
# Write a Python program to find those numbers which are divisible by 7 and multiple of 5, between 1500 and 2700 (both included).

# %%
for i in range(1500,2701):
  if i % 7 == 0 and i % 5 == 0:
    print(i)
# Out:
# 1505
# 1540
# 1575
# 1610
# 1645
# 1680
# 1715
# 1750
# 1785
# 1820
# 1855
# 1890
# 1925
# 1960
# 1995
# 2030
# 2065
# 2100
# 2135
# 2170
# 2205
# 2240
# 2275
# 2310
# 2345
# 2380
# 2415
# 2450
# 2485
# 2520
# 2555
# 2590
# 2625
# 2660
# 2695

# %% [markdown]
# QUESTION 7

# %% [markdown]
# Print square of all numbers between 10 to 20 except even numbers

# %%
for i in range(10,21):
  if i % 2 == 0:
    pass
  else:
    print(i**2)
# Out:
# 121
# 169
# 225
# 289
# 361

# %% [markdown]
# QUESTION 8

# %% [markdown]
# Your Marks for five Test(test1 to test5) looks like this,
#
# marks_list = [65, 75, 2100, 95, 83]
#
# Write a program that asks you to enter marks and program should tell you in which test that marks occurred. If marks is not found then it should print that as well.

# %%
marks_list = [65, 75, 2100, 95, 83]
marks = int(input("Enter the marks: "))
if marks in marks_list:
  print("This is the score of test", marks_list.index(marks) + 1)
else:
  print("Marks not found")
# Out:
# Enter the marks: 2100
# This is the score of test 3
